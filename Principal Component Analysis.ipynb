# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
tumor = pd.read_csv(r"C:\Users\KAsab\Desktop\YOUTUBE R VIDEOS DATASETS\tumor.csv")

# %%
tumor.head()
# Out:
#    Sample code number  Clump Thickness  Uniformity of Cell Size  \
# 0             1000025                5                        1
# 1             1002945                5                        4
# 2             1015425                3                        1
# 3             1016277                6                        8
# 4             1017023                4                        1
#
#    Uniformity of Cell Shape  Marginal Adhesion  Single Epithelial Cell Size  \
# 0                         1                  1                            2
# 1                         4                  5                            7
# 2                         1                  1                            2
# 3                         8                  1                            3
# 4                         1                  3                            2
#
#    Bare Nuclei  Bland Chromatin  Normal Nucleoli  Mitoses  Class
# ...

# %%
spotify = pd.read_csv(r"C:\Users\KAsab\Desktop\YOUTUBE R VIDEOS DATASETS\spotify.csv")

# %%
spotify.head()
# Out:
#    Unnamed: 0                track_id                 artists  \
# 0           0  5SuOikwiRyPMVoIQDJUgSV             Gen Hoshino
# 1           1  4qPNDBW1i3p13qLCt0Ki3A            Ben Woodward
# 2           2  1iJBSr7s7jYXzM8EGcbK5b  Ingrid Michaelson;ZAYN
# 3           3  6lfxq3CG4xtTiEg7opyCyx            Kina Grannis
# 4           4  5vjLSffimiIP26QG5WcN2K        Chord Overstreet
#
#                                           album_name  \
# 0                                             Comedy
# 1                                   Ghost (Acoustic)
# 2                                     To Begin Again
# 3  Crazy Rich Asians (Original Motion Picture Sou...
# 4                                            Hold On
#
#                    track_name  popularity  duration_ms  explicit  \
# 0                      Comedy          73       230666     False
# 1            Ghost - Acoustic          55       149610     False
# 2              To Begin Again          57       210826     False
# ...

# %%
spotify.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 114000 entries, 0 to 113999
# Data columns (total 21 columns):
#  #   Column            Non-Null Count   Dtype
# ---  ------            --------------   -----
#  0   Unnamed: 0        114000 non-null  int64
#  1   track_id          114000 non-null  object
#  2   artists           113999 non-null  object
#  3   album_name        113999 non-null  object
#  4   track_name        113999 non-null  object
#  5   popularity        114000 non-null  int64
#  6   duration_ms       114000 non-null  int64
#  7   explicit          114000 non-null  bool
#  8   danceability      114000 non-null  float64
#  9   energy            114000 non-null  float64
#  10  key               114000 non-null  int64
#  11  loudness          114000 non-null  float64
#  12  mode              114000 non-null  int64
#  13  speechiness       114000 non-null  float64
#  14  acousticness      114000 non-null  float64
#  15  instrumentalness  114000 non-null  float64
# ...

# %%
from sklearn.preprocessing import StandardScaler
from sklearn.decomposition import PCA

# %%
pca = PCA()
ss = StandardScaler()

# %%
df = spotify.select_dtypes(include = "number")
df = df.iloc[:,1:]

# %%
df.head()
# Out:
#    popularity  duration_ms  danceability  energy  key  loudness  mode  \
# 0          73       230666         0.676  0.4610    1    -6.746     0
# 1          55       149610         0.420  0.1660    1   -17.235     1
# 2          57       210826         0.438  0.3590    0    -9.734     1
# 3          71       201933         0.266  0.0596    0   -18.515     1
# 4          82       198853         0.618  0.4430    2    -9.681     1
#
#    speechiness  acousticness  instrumentalness  liveness  valence    tempo  \
# 0       0.1430        0.0322          0.000001    0.3580    0.715   87.917
# 1       0.0763        0.9240          0.000006    0.1010    0.267   77.489
# 2       0.0557        0.2100          0.000000    0.1170    0.120   76.332
# 3       0.0363        0.9050          0.000071    0.1320    0.143  181.740
# 4       0.0526        0.4690          0.000000    0.0829    0.167  119.949
#
#    time_signature
# 0               4
# 1               4
# 2               4
# ...

# %%
features= ss.fit_transform(df)

# %%
features
# Out:
# array([[ 1.78262719,  0.02457516,  0.62924424, ...,  0.92930586,
#         -1.14186279,  0.22182318],
#        [ 0.97563254, -0.73085898, -0.84590798, ..., -0.79868969,
#         -1.48971712,  0.22182318],
#        [ 1.06529861, -0.16033174, -0.74218634, ..., -1.36568823,
#         -1.528312  ,  0.22182318],
#        ...,
#        [-0.50385765,  0.40482724,  0.35841551, ...,  1.03730558,
#          0.34125493,  0.22182318],
#        [ 0.34797004,  0.52064569,  0.11639835, ..., -0.23554828,
#          0.4607423 ,  0.22182318],
#        [-0.50385765,  0.12858529, -0.23510276, ...,  0.90230593,
#         -1.43270877,  0.22182318]])

# %%
pca = PCA(n_components = 0.99,whiten = True)

# %%
features_pca = pca.fit_transform(features)

# %%
print("original number of features",features.shape[1])
print("Reduced number of features",features_pca.shape[1])
# Out:
# original number of features 14
# Reduced number of features 13

# %%
pca1 = PCA()

# %%
pca = PCA(n_components = 0.95,whiten = True)

# %%
features1 = pca.fit_transform(features)
features1.shape[1]
# Out:
# 12

# %%
df_pca = pd.DataFrame(features_pca)

# %%
df_pca.head()
# Out:
#          0         1         2         3         4         5         6   \
# 0 -0.434971 -0.748369 -0.205074  0.315542 -1.483556  1.864277  0.050662
# 1  1.898984 -1.209540 -0.271578 -1.079077 -0.944801  1.000973 -0.277021
# 2  0.808529 -0.017569  0.084861 -1.437430 -0.945713  1.431233  0.433728
# 3  2.202995  0.207450 -0.717583 -2.238375 -1.729331 -1.342146 -1.311243
# 4  0.537689 -0.408248  0.448608 -1.446348 -1.830310  0.856812 -0.683754
#
#          7         8         9         10        11        12
# 0 -1.392916  0.145853  0.811562 -0.556661  0.432866  1.323716
# 1 -0.220077 -0.684987 -0.047593  1.047250  0.536838  0.475860
# 2 -0.810399 -0.995193 -0.595488  1.168727 -0.256045  1.055407
# 3 -0.654187  2.030062  0.644669  0.354594 -0.431765  0.925287
# 4 -0.331599  0.111235 -0.730790  0.450871 -0.995827 -0.084458

# %%
df.corr()
# Out:
#                   popularity  duration_ms  danceability    energy       key  \
# popularity          1.000000    -0.007101      0.035448  0.001056 -0.003853
# duration_ms        -0.007101     1.000000     -0.073426  0.058523  0.008114
# danceability        0.035448    -0.073426      1.000000  0.134325  0.036469
# energy              0.001056     0.058523      0.134325  1.000000  0.048006
# key                -0.003853     0.008114      0.036469  0.048006  1.000000
# loudness            0.050423    -0.003470      0.259077  0.761690  0.038590
# mode               -0.013931    -0.035556     -0.069219 -0.078362 -0.135916
# speechiness        -0.044927    -0.062600      0.108626  0.142509  0.020418
# acousticness       -0.025472    -0.103788     -0.171533 -0.733906 -0.040937
# instrumentalness   -0.095139     0.124371     -0.185606 -0.181879 -0.006823
# liveness           -0.005387     0.010321     -0.131617  0.184796 -0.001600
# ...

# %%
correlation = df.corr()
plt.figure(figsize=(10,10))
sns.heatmap(correlation, vmax=1, square=True,annot=True,cmap='viridis', cbar = None)

plt.title('Correlation between different fearures')
# Out:
# Text(0.5, 1.0, 'Correlation between different fearures')

# %%
correlation = df.corr()
plt.figure(figsize=(10,10))
sns.heatmap(correlation, vmax=1, square=True,annot=True,cmap='Blues', cbar = None)

plt.title('Correlation between different fearures')
# Out:
# Text(0.5, 1.0, 'Correlation between different fearures')

# %%
spotify.head()
# Out:
#    Unnamed: 0                track_id                 artists  \
# 0           0  5SuOikwiRyPMVoIQDJUgSV             Gen Hoshino
# 1           1  4qPNDBW1i3p13qLCt0Ki3A            Ben Woodward
# 2           2  1iJBSr7s7jYXzM8EGcbK5b  Ingrid Michaelson;ZAYN
# 3           3  6lfxq3CG4xtTiEg7opyCyx            Kina Grannis
# 4           4  5vjLSffimiIP26QG5WcN2K        Chord Overstreet
#
#                                           album_name  \
# 0                                             Comedy
# 1                                   Ghost (Acoustic)
# 2                                     To Begin Again
# 3  Crazy Rich Asians (Original Motion Picture Sou...
# 4                                            Hold On
#
#                    track_name  popularity  duration_ms  explicit  \
# 0                      Comedy          73       230666     False
# 1            Ghost - Acoustic          55       149610     False
# 2              To Begin Again          57       210826     False
# ...

# %%
cols = spotify.select_dtypes(include = "number").columns.tolist()

# %%
cols = cols[1:]
print(cols)
# Out:
# ['duration_ms', 'danceability', 'energy', 'key', 'loudness', 'mode', 'speechiness', 'acousticness', 'instrumentalness', 'liveness', 'valence', 'tempo', 'time_signature']

# %%
cols =['duration_ms', 'danceability', 'energy', 'key', 'loudness', 'mode', 'speechiness', 'acousticness', 'instrumentalness', 'liveness', 'valence', 'tempo', 'time_signature',"track_genre"]

# %%
df = spotify[cols]

# %%
df.head()
# Out:
#    duration_ms  danceability  energy  key  loudness  mode  speechiness  \
# 0       230666         0.676  0.4610    1    -6.746     0       0.1430
# 1       149610         0.420  0.1660    1   -17.235     1       0.0763
# 2       210826         0.438  0.3590    0    -9.734     1       0.0557
# 3       201933         0.266  0.0596    0   -18.515     1       0.0363
# 4       198853         0.618  0.4430    2    -9.681     1       0.0526
#
#    acousticness  instrumentalness  liveness  valence    tempo  time_signature  \
# 0        0.0322          0.000001    0.3580    0.715   87.917               4
# 1        0.9240          0.000006    0.1010    0.267   77.489               4
# 2        0.2100          0.000000    0.1170    0.120   76.332               4
# 3        0.9050          0.000071    0.1320    0.143  181.740               3
# 4        0.4690          0.000000    0.0829    0.167  119.949               4
#
#   track_genre
# 0    acoustic
# 1    acoustic
# 2    acoustic
# ...

# %%
corr_metrics  = df.iloc[:,:13].corr()

# %%
corr_metrics.style.background_gradient()
# Out:
# <style type="text/css">
# #T_c7094_row0_col0, #T_c7094_row1_col1, #T_c7094_row2_col2, #T_c7094_row3_col3, #T_c7094_row4_col4, #T_c7094_row5_col5, #T_c7094_row6_col6, #T_c7094_row7_col7, #T_c7094_row8_col8, #T_c7094_row9_col9, #T_c7094_row10_col10, #T_c7094_row11_col11, #T_c7094_row12_col12 {
#   background-color: #023858;
#   color: #f1f1f1;
# }
# #T_c7094_row0_col1, #T_c7094_row12_col9 {
#   background-color: #f1ebf4;
#   color: #000000;
# }
# #T_c7094_row0_col2, #T_c7094_row4_col10 {
#   background-color: #86b0d3;
#   color: #000000;
# }
# #T_c7094_row0_col3, #T_c7094_row0_col9, #T_c7094_row0_col10, #T_c7094_row5_col9 {
#   background-color: #ece7f2;
#   color: #000000;
# }
# #T_c7094_row0_col4 {
#   background-color: #a8bedc;
#   color: #000000;
# }
# #T_c7094_row0_col5, #T_c7094_row4_col5, #T_c7094_row4_col7, #T_c7094_row7_col3, #T_c7094_row12_col6 {
#   background-color: #f2ecf5;
#   color: #000000;
# }
# #T_c7094_row0_col6 {
#   background-color: #fbf4f9;
#   color: #000000;
# ...

# %%
labels = df["track_genre"].values

# %%
labels
# Out:
# array(['acoustic', 'acoustic', 'acoustic', ..., 'world-music',
#        'world-music', 'world-music'], dtype=object)

# %%
features = df.drop(["track_genre"],axis = 1).values

# %%
features_std = ss.fit_transform(features)

# %%
features_std
# Out:
# array([[ 0.02457516,  0.62924424, -0.71714792, ...,  0.92930586,
#         -1.14186279,  0.22182318],
#        [-0.73085898, -0.84590798, -1.88997974, ..., -0.79868969,
#         -1.48971712,  0.22182318],
#        [-0.16033174, -0.74218634, -1.12266943, ..., -1.36568823,
#         -1.528312  ,  0.22182318],
#        ...,
#        [ 0.40482724,  0.35841551, -1.24194046, ...,  1.03730558,
#          0.34125493,  0.22182318],
#        [ 0.52064569,  0.11639835, -0.53824138, ..., -0.23554828,
#          0.4607423 ,  0.22182318],
#        [ 0.12858529, -0.23510276, -0.6137797 , ...,  0.90230593,
#         -1.43270877,  0.22182318]])

# %%
from sklearn.model_selection import train_test_split

# %%
features_train,features_test,labels_train,labels_test = train_test_split(features_std,labels,test_size = 0.2,random_state = 123)

# %%
pca = PCA()

# %%
pca.fit(features_train)
# Out:
# PCA()

# %%
exp_variance = pca.explained_variance_ratio_

# %%
exp_variance
# Out:
# array([0.22836747, 0.11777606, 0.09794713, 0.08967767, 0.07536957,
#        0.06992122, 0.06789079, 0.06389185, 0.06094437, 0.05728791,
#        0.03519233, 0.0250257 , 0.01070794])

# %%
fig,ax = plt.subplots(figsize = (8,6))
sns.barplot(exp_variance)
ax.set_xlabel("Principal Component Number")
# Out:
# Text(0.5, 0, 'Principal Component Number')

# %%
## cumulative explained variance plot

# %%
cum_exp_variance = np.cumsum(exp_variance)

# %%
fig,ax = plt.subplots()
ax.plot(cum_exp_variance)

# %%
# Plot the cumulative explained variance and draw a dashed line at 0.85.
fig,ax = plt.subplots()
ax.plot(cum_exp_variance)
ax.axhline(y = 0.85,linestyle = "--",color = "red")

# %%
pca = PCA(n_components = 7)

# %%
train_pca = pca.fit_transform(features_train)
test_pca = pca.fit_transform(features_test)

# %%
train_pca
# Out:
# array([[-1.6491009 ,  1.2699461 , -2.14351984, ...,  0.20291205,
#          1.56071684,  2.27212967],
#        [-0.63983083,  0.90700112, -1.72156997, ..., -0.04479035,
#          0.85407642,  2.48912873],
#        [ 1.03654205, -0.16934689,  1.3752803 , ..., -0.20016298,
#         -1.24824384,  0.26058395],
#        ...,
#        [ 4.65090778,  0.25456882, -1.38498136, ..., -2.53579994,
#          1.96999987, -4.27109064],
#        [ 0.07160589,  2.11396395,  0.03917004, ..., -1.68337595,
#         -0.62377036,  1.07885335],
#        [ 1.376152  , -0.48673559,  0.33877499, ..., -0.61285498,
#         -0.59724222, -0.22185182]])

# %%
df_pca = pd.DataFrame(train_pca)
df_pca.head()
# Out:
#           0         1         2         3         4         5         6
# 0 -1.649101  1.269946 -2.143520  0.409794  0.202912  1.560717  2.272130
# 1 -0.639831  0.907001 -1.721570  0.304117 -0.044790  0.854076  2.489129
# 2  1.036542 -0.169347  1.375280 -0.126111 -0.200163 -1.248244  0.260584
# 3 -0.614247  2.634299  1.244927  0.291306 -0.119451 -1.179294 -1.183911
# 4 -1.039560 -1.622399  0.375792 -0.741913  0.319196  0.583166 -0.038999

# %%
sns.scatterplot(
    x = 0,
    y = 1,
    data = df_pca,
    
)
# Out:
# <Axes: xlabel='0', ylabel='1'>

# %%
tumor = pd.read_csv(r"C:\Users\KAsab\Downloads\breast-cancer-wisconsin.csv")

# %%
tumor.head()
# Out:
#    CodeNumber  ClumpThickness  UniformityCellSize  UniformityCellShape  \
# 0     1002945               5                   4                    4
# 1     1015425               3                   1                    1
# 2     1016277               6                   8                    8
# 3     1017023               4                   1                    1
# 4     1017122               8                  10                   10
#
#    MarginalAdhesion  SingleEpithelialCellSize BareNuclei  BlandChromatin  \
# 0                 5                         7         10               3
# 1                 1                         2          2               3
# 2                 1                         3          4               3
# 3                 3                         2          1               3
# 4                 8                         7         10               9
#
#    NormalNucleoli  Mitoses  CancerType
# 0               2        1           2
# ...

# %%
tumor.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 698 entries, 0 to 697
# Data columns (total 11 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   CodeNumber                698 non-null    int64
#  1   ClumpThickness            698 non-null    int64
#  2   UniformityCellSize        698 non-null    int64
#  3   UniformityCellShape       698 non-null    int64
#  4   MarginalAdhesion          698 non-null    int64
#  5   SingleEpithelialCellSize  698 non-null    int64
#  6   BareNuclei                698 non-null    object
#  7   BlandChromatin            698 non-null    int64
#  8   NormalNucleoli            698 non-null    int64
#  9   Mitoses                   698 non-null    int64
#  10  CancerType                698 non-null    int64
# dtypes: int64(10), object(1)
# memory usage: 60.1+ KB

# %%
tumor.isna().sum()
# Out:
# CodeNumber                   0
# ClumpThickness               0
# UniformityCellSize           0
# UniformityCellShape          0
# MarginalAdhesion             0
# SingleEpithelialCellSize     0
# BareNuclei                  16
# BlandChromatin               0
# NormalNucleoli               0
# Mitoses                      0
# CancerType                   0
# dtype: int64

# %%
tumor.drop(["BareNuclei"],axis = 1,inplace = True)

# %%
X = tumor.iloc[:,:9]
y = tumor.iloc[:,9]

# %%
X_train,X_test,y_train,y_test = train_test_split(X,y)

# %%
cols = tumor.iloc[:,:9].columns.tolist()

# %%
X_train = ss.fit_transform(X_train)

# %%
X_train = pd.DataFrame(X_train,columns = cols)

# %%
X_train
# Out:
#      CodeNumber  ClumpThickness  UniformityCellSize  UniformityCellShape  \
# 0      0.160688       -0.860309           -0.685394            -0.733248
# 1      0.109989       -0.144412           -0.685394            -0.733248
# 2      0.213858        2.003282            1.644437             2.342863
# 3     -0.011702        0.213537           -0.685394            -0.733248
# 4     -0.635547       -0.502360           -0.685394            -0.733248
# ..          ...             ...                 ...                  ...
# 518   -0.348584       -0.860309            1.311604             2.342863
# 519    0.029254        0.571486           -0.019728            -0.391457
# 520    0.414372        0.213537           -0.685394            -0.733248
# 521    0.284193        2.003282            1.644437             1.659283
# 522    0.214688       -0.502360           -0.685394            -0.733248
#
#      MarginalAdhesion  SingleEpithelialCellSize  BlandChromatin  \
# ...

# %%
X_train.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 523 entries, 0 to 522
# Data columns (total 9 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   CodeNumber                523 non-null    float64
#  1   ClumpThickness            523 non-null    float64
#  2   UniformityCellSize        523 non-null    float64
#  3   UniformityCellShape       523 non-null    float64
#  4   MarginalAdhesion          523 non-null    float64
#  5   SingleEpithelialCellSize  523 non-null    float64
#  6   BlandChromatin            523 non-null    float64
#  7   NormalNucleoli            523 non-null    float64
#  8   Mitoses                   523 non-null    float64
# dtypes: float64(9)
# memory usage: 36.9 KB

# %%
X_train.describe().round(3)
# Out:
#        CodeNumber  ClumpThickness  UniformityCellSize  UniformityCellShape  \
# count     523.000         523.000             523.000              523.000
# mean       -0.000          -0.000              -0.000                0.000
# std         1.001           1.001               1.001                1.001
# min        -1.627          -1.218              -0.685               -0.733
# 25%        -0.320          -0.860              -0.685               -0.733
# 50%         0.166          -0.144              -0.685               -0.733
# 75%         0.268           0.571               0.313                0.463
# max        20.063           2.003               2.310                2.343
#
#        MarginalAdhesion  SingleEpithelialCellSize  BlandChromatin  \
# count           523.000                   523.000         523.000
# mean             -0.000                     0.000          -0.000
# std               1.001                     1.001           1.001
# ...

# %%
pca1 = PCA()

# %%
pca1
# Out:
# PCA()

# %%
X_pca1 = pca1.fit_transform(X_train)

# %%
exp_variance1 = pca1.explained_variance_ratio_

# %%
fig,ax = plt.subplots(figsize = (8,6))
sns.barplot(exp_variance1)
ax.set_xlabel("Number of components")
# Out:
# Text(0.5, 0, 'Number of components')

# %%
cum_explained_variance = np.cumsum(exp_variance1)

# %%
cum_explained_variance
# Out:
# array([0.59090228, 0.70229506, 0.78333603, 0.84351607, 0.88870714,
#        0.92745456, 0.95972874, 0.989035  , 1.        ])

# %%
sns.lineplot(cum_explained_variance)
# Out:
# <Axes: >

# %%
pca2 = PCA(n_components = 2)

# %%
X_pca2 = pca2.fit_transform(X_train)

# %%
colormap = plt.colormaps.get_cmap("coolwarm")

# %%
plt.figure()
scatter = plt.scatter(X_pca2[:,0],X_pca2[:,1], c = y_train,cmap = colormap)
plt.xlabel("PC1")
plt.ylabel("PCA2")
plt.colorbar(scatter,label = "Cancer Type")
plt.show()

# %%
fig,ax = plt.subplots(figsize = (8,6))
sns.barplot(exp_variance1)
ax.set_xlabel("Number of components")

sns.lineplot(cum_explained_variance,color = "red")
# Out:
# <Axes: xlabel='Number of components'>
