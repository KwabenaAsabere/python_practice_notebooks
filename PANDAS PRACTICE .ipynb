# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
bloomberg = pd.read_csv(r"C:\Users\KAsab\Downloads\2017class621.csv")

# %%
bloomberg.head()
# Out:
#    id     sex  gender  age  weight  wght18  height                       phys  \
# 0   1    Male    Male   32   163.0   150.0    69.0       Within the past year
# 1   2    Male    Male   29   190.0   180.0    69.0  Within the past 2-5 years
# 2   3  Female  Female   43   110.0   120.0    63.0       Within the past year
# 3   4  Female  Female   24   120.0   122.0    63.0       Within the past year
# 4   5  Female  Female   37   115.0   112.0    62.0       Within the past year
#
#   aspirin vitc  ... sm100age    cursmoke                 wtchange exhrs  \
# 0     NaN  NaN  ...      NaN  Not at all  Maintain current weight   2-3
# 1     NaN  NaN  ...      NaN  Not at all              Lose weight   4-7
# 2     NaN  NaN  ...     21.0    Everyday              Gain weight   2-3
# 3     NaN  Yes  ...      NaN  Not at all  Maintain current weight   2-3
# 4     NaN  Yes  ...      NaN  Not at all  Maintain current weight   4-7
#
# ...

# %%
bloomberg.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 431 entries, 0 to 430
# Data columns (total 27 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   id        431 non-null    int64
#  1   sex       431 non-null    object
#  2   gender    431 non-null    object
#  3   age       431 non-null    int64
#  4   weight    430 non-null    float64
#  5   wght18    429 non-null    float64
#  6   height    430 non-null    float64
#  7   phys      431 non-null    object
#  8   aspirin   376 non-null    object
#  9   vitc      384 non-null    object
#  10  vite      371 non-null    object
#  11  multivit  418 non-null    object
#  12  calcium   377 non-null    object
#  13  blood     369 non-null    object
#  14  chol      367 non-null    object
#  15  health    431 non-null    object
#  16  smoke100  431 non-null    object
#  17  sm100age  40 non-null     float64
#  18  cursmoke  431 non-null    object
#  19  wtchange  431 non-null    object
# ...

# %%
bloomberg.shape
# Out:
# (431, 27)

# %%
bloomberg["program"].unique()
# Out:
# array(['MPH/MPH-MBA/MPH-MSN', 'Other', 'MHS/MS/ScM/MSE/MPP',
#        'PhD/DrPH/ScD', 'Post-doc', 'MSPH', 'BA'], dtype=object)

# %%
mask = bloomberg["program"].str.contains("DrPH")

# %%
doctoral = bloomberg.loc[mask]
doctoral.head()
# Out:
#     id     sex  gender  age  weight  wght18  height  \
# 5    6  Female  Female   25   135.0   135.0    69.0
# 8    9  Female  Female   27   112.0   116.0    63.0
# 10  11    Male    Male   47   314.0   155.0    73.0
# 12  13  Female  Female   26   160.0   130.0    65.0
# 29  30  Female  Female   37   165.0   110.0    65.0
#
#                          phys aspirin vitc  ... sm100age    cursmoke  \
# 5        Within the past year      No  Yes  ...      NaN  Not at all
# 8        Within the past year     NaN  NaN  ...      NaN  Not at all
# 10       Within the past year      No   No  ...      NaN  Not at all
# 12       Within the past year      No   No  ...     18.0  Not at all
# 29  Within the past 1-2 years      No   No  ...      NaN  Not at all
#
#                    wtchange exhrs  exintens     degree       program  mstatus  \
# 5   Maintain current weight  8-13      High    Masters  PhD/DrPH/ScD      Yes
# ...

# %%
bloomberg["degree"].value_counts()
# Out:
# degree
# Bachelors         228
# Masters            79
# MD                 61
# Other Doctoral     33
# Other              30
# Name: count, dtype: int64

# %%
ym = (bloomberg["degree"] == "Masters") & (bloomberg["age"] >25)
ym
# Out:
# 0      False
# 1      False
# 2       True
# 3      False
# 4      False
#        ...
# 426     True
# 427    False
# 428    False
# 429     True
# 430    False
# Length: 431, dtype: bool

# %%
masters =bloomberg.loc[ym,["sex","age","weight","height","exhrs"]]
masters.head()
# Out:
#        sex  age  weight  height exhrs
# 2   Female   43   110.0    63.0   2-3
# 10    Male   47   314.0    73.0   2-3
# 12  Female   26   160.0    65.0   2-3
# 29  Female   37   165.0    65.0   2-3
# 40  Female   29   119.0    65.0   2-3

# %%
masters["exhrs"].value_counts().plot.bar(edgecolor = "black",color = "skyblue")
plt.xlabel("Hours of Exercise");
plt.ylabel("Frequency");

# %%
masters.plot.scatter("weight","height")
plt.grid();

# %%
bloomberg["degree"].value_counts().plot.barh()
plt.grid();

# %%
df = pd.read_excel(r"C:\Users\KAsab\Downloads\Customer Call List (1).xlsx")

# %%
df.head()
# Out:
#    CustomerID First_Name Last_Name  Phone_Number  \
# 0        1001      Frodo   Baggins  123-545-5421
# 1        1002       Abed     Nadir  123/643/9775
# 2        1003     Walter    /White    7066950392
# 3        1004     Dwight   Schrute  123-543-2345
# 4        1005        Jon      Snow  876|678|3469
#
#                                  Address Paying Customer Do_Not_Contact  \
# 0                  123 Shire Lane, Shire             Yes             No
# 1                    93 West Main Street              No            Yes
# 2                     298 Drugs Driveway               N            NaN
# 3  980 Paper Avenue, Pennsylvania, 18503             Yes              Y
# 4                       123 Dragons Road               Y             No
#
#    Not_Useful_Column
# 0               True
# 1              False
# 2               True
# 3               True
# 4               True

# %%
df.shape
# Out:
# (21, 8)

# %%
df.drop_duplicates(inplace = True)
df
# Out:
#     CustomerID First_Name    Last_Name  Phone_Number  \
# 0         1001      Frodo      Baggins  123-545-5421
# 1         1002       Abed        Nadir  123/643/9775
# 2         1003     Walter       /White    7066950392
# 3         1004     Dwight      Schrute  123-543-2345
# 4         1005        Jon         Snow  876|678|3469
# 5         1006        Ron      Swanson  304-762-2467
# 6         1007       Jeff       Winger           NaN
# 7         1008   Sherlock       Holmes  876|678|3469
# 8         1009    Gandalf          NaN           N/a
# 9         1010      Peter       Parker  123-545-5421
# 10        1011    Samwise       Gamgee           NaN
# 11        1012      Harry    ...Potter    7066950392
# 12        1013        Don       Draper  123-543-2345
# 13        1014     Leslie        Knope  876|678|3469
# 14        1015       Toby  Flenderson_  304-762-2467
# 15        1016        Ron      Weasley  123-545-5421
# 16        1017   Michael         Scott  123/643/9775
# ...
