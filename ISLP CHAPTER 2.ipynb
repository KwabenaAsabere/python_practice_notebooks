# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
adverts = pd.read_csv(r"C:\Users\KAsab\Desktop\PYTHON\ISLP DATASETS\Advertising.csv")

# %%
adverts.head(10)
# Out:
#    Unnamed: 0     TV  radio  newspaper  sales
# 0           1  230.1   37.8       69.2   22.1
# 1           2   44.5   39.3       45.1   10.4
# 2           3   17.2   45.9       69.3    9.3
# 3           4  151.5   41.3       58.5   18.5
# 4           5  180.8   10.8       58.4   12.9
# 5           6    8.7   48.9       75.0    7.2
# 6           7   57.5   32.8       23.5   11.8
# 7           8  120.2   19.6       11.6   13.2
# 8           9    8.6    2.1        1.0    4.8
# 9          10  199.8    2.6       21.2   10.6

# %%
adverts = adverts.iloc[:,1:]

# %%
adverts.head(10)
# Out:
#       TV  radio  newspaper  sales
# 0  230.1   37.8       69.2   22.1
# 1   44.5   39.3       45.1   10.4
# 2   17.2   45.9       69.3    9.3
# 3  151.5   41.3       58.5   18.5
# 4  180.8   10.8       58.4   12.9
# 5    8.7   48.9       75.0    7.2
# 6   57.5   32.8       23.5   11.8
# 7  120.2   19.6       11.6   13.2
# 8    8.6    2.1        1.0    4.8
# 9  199.8    2.6       21.2   10.6

# %%
income1 = pd.read_csv(r"C:\Users\KAsab\Desktop\PYTHON\ISLP DATASETS\Income1.csv")

# %%
income2 = pd.read_csv(r"C:\Users\KAsab\Desktop\PYTHON\ISLP DATASETS\Income2.csv")

# %%
income1.head()
# Out:
#    Unnamed: 0  Education     Income
# 0           1  10.000000  26.658839
# 1           2  10.401338  27.306435
# 2           3  10.842809  22.132410
# 3           4  11.244147  21.169841
# 4           5  11.645485  15.192634

# %%
income2.sample(10)
# Out:
#     Unnamed: 0  Education   Seniority     Income
# 9           10  10.000000  113.103448  45.655529
# 13          14  16.620690   94.482759  66.601792
# 10          11  13.724138   51.034483  31.913808
# 22          23  17.448276   94.482759  72.078924
# 1            2  18.275862  119.310345  92.579135
# 16          17  14.137931   20.000000  28.816301
# 17          18  16.620690   44.827586  57.681694
# 7            8  21.172414   82.068966  79.811030
# 0            1  21.586207  113.103448  99.917173
# 21          22  14.551724  137.931034  53.532106

# %%
fig,ax  = plt.subplots(nrows = 3,ncols = 1,figsize = (8,6))
ax[0] = ax[0].scatter(
    data = adverts,
    x = "TV",
    y = "sales"
)

ax[1].scatter(
    data = adverts,
    x = "newspaper",
    y = "sales"
)

ax[2].scatter(
    data = adverts,
    x = "radio",
    y = "sales"
)

# %%
from sklearn.model_selection import train_test_split

# %%
adverts.head()
# Out:
#       TV  radio  newspaper  sales
# 0  230.1   37.8       69.2   22.1
# 1   44.5   39.3       45.1   10.4
# 2   17.2   45.9       69.3    9.3
# 3  151.5   41.3       58.5   18.5
# 4  180.8   10.8       58.4   12.9

# %%
X = adverts.iloc[:,:3].values
y = adverts.iloc[:,-1]

# %%
y.head()
# Out:
# 0    22.1
# 1    10.4
# 2     9.3
# 3    18.5
# 4    12.9
# Name: sales, dtype: float64

# %%
X[:10]
# Out:
# array([[230.1,  37.8,  69.2],
#        [ 44.5,  39.3,  45.1],
#        [ 17.2,  45.9,  69.3],
#        [151.5,  41.3,  58.5],
#        [180.8,  10.8,  58.4],
#        [  8.7,  48.9,  75. ],
#        [ 57.5,  32.8,  23.5],
#        [120.2,  19.6,  11.6],
#        [  8.6,   2.1,   1. ],
#        [199.8,   2.6,  21.2]])

# %%
ames = pd.read_csv(r"C:\Users\KAsab\Desktop\ALL CSV FILES - 2nd Edition\ames_housing.csv")

# %%
ames.head()
# Out:
#    Lot_Frontage  Lot_Area Street           Lot_Shape Utilities Neighborhood  \
# 0           141     31770   Pave  Slightly_Irregular    AllPub   North_Ames
# 1            80     11622   Pave             Regular    AllPub   North_Ames
# 2            81     14267   Pave  Slightly_Irregular    AllPub   North_Ames
# 3            93     11160   Pave             Regular    AllPub   North_Ames
# 4            74     13830   Pave  Slightly_Irregular    AllPub      Gilbert
#
#   Bldg_Type House_Style   Overall_Cond  Year_Built  ... TotRms_AbvGrd  \
# 0    OneFam   One_Story        Average        1960  ...             7
# 1    OneFam   One_Story  Above_Average        1961  ...             5
# 2    OneFam   One_Story  Above_Average        1958  ...             6
# 3    OneFam   One_Story        Average        1968  ...             8
# 4    OneFam   Two_Story        Average        1997  ...             6
#
#    Garage_Finish  Garage_Cars  Garage_Area  Pool_Area  Year_Sold  Sale_Type  \
# ...

# %%
ames.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2930 entries, 0 to 2929
# Data columns (total 28 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Lot_Frontage   2930 non-null   int64
#  1   Lot_Area       2930 non-null   int64
#  2   Street         2930 non-null   object
#  3   Lot_Shape      2930 non-null   object
#  4   Utilities      2930 non-null   object
#  5   Neighborhood   2930 non-null   object
#  6   Bldg_Type      2930 non-null   object
#  7   House_Style    2930 non-null   object
#  8   Overall_Cond   2930 non-null   object
#  9   Year_Built     2930 non-null   int64
#  10  Roof_Style     2930 non-null   object
#  11  Total_Bsmt_SF  2930 non-null   int64
#  12  First_Flr_SF   2930 non-null   int64
#  13  Second_Flr_SF  2930 non-null   int64
#  14  Gr_Liv_Area    2930 non-null   int64
#  15  Full_Bath      2930 non-null   int64
#  16  Half_Bath      2930 non-null   int64
# ...
